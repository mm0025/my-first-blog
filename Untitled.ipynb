# %%
1+1
# Out:
# 2

# %%
"이민하"
# Out:
# '이민하'

# %%
'이민하'
# Out:
# '이민하'

# %%
'"이민하"'
# Out:
# '"이민하"'

# %%
"3000*이민하"
# Out:
# '3000*이민하'

# %%
3000*이민하
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2f9431e30d2e> in <module>()
# ----> 1 3000*이민하
#
# NameError: name '이민하' is not defined

# %%
3000*"이민하"+"이동욱"
# Out:
# '이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이민하이
# ...

# %%
True False
# Out:
#   File "<ipython-input-9-dcc57eed4250>", line 1
#     True False
#              ^
# SyntaxError: invalid syntax

# %%
True
# Out:
# True

# %%
1<2
# Out:
# True

# %%
if True:
    print "h"
# Out:
#   File "<ipython-input-12-5981b4abb25d>", line 2
#     print "h"
#             ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
if True:
    print("h")
# Out:
# h

# %%
m="mouse"

# %%
m
# Out:
# 'mouse'

# %%
숫자리스트 = [1,2,3,4,5,6,7]

# %%
숫자리스트
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
우리반명부 = ["지니" , "미나" , "헤리", "주니", "야"]

# %%
우리반명부[0]
# Out:
# '지니'

# %%
우리반명부[-1]
# Out:
# '헤리'

# %%
우리반명부[2:]
# Out:
# ['헤리']

# %%
우리반명부[2:4]
# Out:
# ['헤리', '주니']

# %%
우리반명부[:-1]
# Out:
# ['지니', '미나', '헤리', '주니']

# %%
우리반명부[0:1:5]
# Out:
# ['지니']

# %%
우리반명부[::-1]
# Out:
# ['야', '주니', '헤리', '미나', '지니']

# %%
우리반소개 = "우리반 친구들 엄청 마나요"

# %%
우리반소개 [0]
# Out:
# '우'

# %%
우리반소개[0]
# Out:
# '우'

# %%
동물들 = {
    "포유류":"사자", 
    "파충류":"도마뱀"
# Out:
#   File "<ipython-input-1-8c0eba08c7d5>", line 3
#     "파충류":"도마뱀"
#                ^
# SyntaxError: unexpected EOF while parsing

# %%
동물들 = {
    "포유류":"사자", 
    "파충류":"도마뱀"
# Out:
#   File "<ipython-input-2-8c0eba08c7d5>", line 3
#     "파충류":"도마뱀"
#                ^
# SyntaxError: unexpected EOF while parsing

# %%
동물들 = {
    "포유류":"사자", 
    "파충류":"도마뱀"
}

# %%
동물들["포유류"]
# Out:
# '사자'

# %%
동물들["파충류"]
# Out:
# '도마뱀'

# %%
def FF(2):
    return "DD" * 10
# Out:
#   File "<ipython-input-6-2e5783108396>", line 1
#     def FF(2):
#            ^
# SyntaxError: invalid syntax

# %%
def FF(숫자):
    return 10 * 숫자

# %%
FF
# Out:
# <function __main__.FF>

# %%
FF(100)
# Out:
# 'DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD'

# %%
FF("H")
# Out:
# 'HHHHHHHHHH'

# %%
"Runnin' down the hill"
# Out:
# "Runnin' down the hill"

# %%
'Runnin\' down the hill'
# Out:
# "Runnin' down the hill"

# %%
"Ola".upper()
# Out:
# 'OLA'

# %%
len("Ola")
# Out:
# 3
